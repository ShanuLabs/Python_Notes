# %%
import array
a=array.array("i",[36,75,8,87,90])
print(a)
# Out:
# array('i', [36, 75, 8, 87, 90])

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
import random
p=random.randint(1,10001)
count=0
if p<99:
    count=count+p
    print(f"the answer is :{count}")
else:
    print(p)
print(random.choice(["s","sa","shan","shanu"]))
# Out:
# 6959
# shanu

# %%
import os
print(os.getcwd())
os.mkdir("11.dir")
# Out:
# c:\Users\LENOVO\Downloads\Data Science\python\linearreg.ipynb
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[51], line 3
#       1 import os
#       2 print(os.getcwd())
# ----> 3 os.mkdir("11.dir")
#       4 open("test.txt", "w")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: '11.dir'

# %%
open("test.txt", "w")
# Out:
# <_io.TextIOWrapper name='test.txt' mode='w' encoding='utf-8'>

# %%
import shutil
shutil.copyfile("test.txt",'kind.txt')
# Out:
# 'kind.txt'

# %%
##Data Serialization
import json
d={"name":"shanu","age":20}
x=json.dumps(d)
print(x,type(x))
parsed=json.loads(x)
print(parsed,type(parsed))
# Out:
# {"name": "shanu", "age": 20} <class 'str'>
# {'name': 'shanu', 'age': 20} <class 'dict'>

# %%
import csv
with open('example.csv', mode='w', newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['shanu', '24'])
with open('example.csv', mode='r') as file:
        reader = csv.reader(file)
        for row in reader:
         print(row)
# Out:
# ['name', 'age']
# ['shanu', '24']

# %%
from datetime import datetime,timedelta
present_time=datetime.now()
print(present_time)
yesterday_time= datetime.now()-timedelta(days=1)
print(yesterday_time)
# Out:
# 2026-08-09 19:37:03.042739
# 2026-08-08 19:37:03.043090

# %%
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1786284687.4698071
# 1786284689.4710624

# %%
import re

pattern = r'\d+'
text = '111 There are 1 apples 456'

match = re.search(pattern, text)
print(match.group())
# Out:
# 111
