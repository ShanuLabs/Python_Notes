# %%
#list
a =[44.5,5,"shanu",True]
print(a,type(a))
print(a[1:4])
print(a[-3:-2])
a[1]="watermelon"
print(a[1:])
a.remove("shanu")
print(a)
# Out:
# [44.5, 5, 'shanu', True] <class 'list'>
# [5, 'shanu', True]
# [5]
# ['watermelon', 'shanu', True]
# [44.5, 'watermelon', True]

# %%
numbers = tuple([1,2,3,4,5,6])
print(numbers,type(numbers))
# Out:
# (1, 2, 3, 4, 5, 6) <class 'tuple'>

# %%
my_set = {1, 2, 4, 5}
my_set.add(3)
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
set1 = {1,2,3,4,5,6}
set2 = {4,5,6,7,8,9}
set1.intersection_update(set2)
print(set1)
# Out:
# {4, 5, 6}

# %%
packed = (1, 'Hello', 3.14)
print(packed)
# Out:
# (1, 'Hello', 3.14)

# %%
packed = (1, "Hello", 3.14)

a, b, c = packed

print(a,b,c)
# Out:
# 1 Hello 3.14

# %%
nested=((1,2,3),("a","b","c"),(True,False))
print(nested[::][::])
# Out:
# ((1, 2, 3), ('a', 'b', 'c'), (True, False))

# %%
nested = ((1,2,3), ("a","b","c"))

for box in nested:
    for object in box:
        print(object,end=" ")
# Out:
# 1 2 3 a b c
